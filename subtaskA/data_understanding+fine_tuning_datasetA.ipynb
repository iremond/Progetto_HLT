# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rcParams
from cycler import cycler

# -- Figure size --
rcParams['figure.figsize'] = (12, 4)
# -- Saving Options --
rcParams['savefig.bbox'] = 'tight'
rcParams['savefig.dpi'] = 500
rcParams['savefig.transparent'] = True
# -- Plot Styles --
rcParams['lines.linewidth'] = 0.3
teal = (106 / 256, 197 / 256, 179 / 256)
navy = (56 / 256, 74 / 256, 143 / 256)
pink = [199 / 255, 99 / 255, 150 / 255]
rcParams['axes.prop_cycle'] = cycler(color=[teal, navy, pink])

# %%
from tqdm.notebook import tqdm

# %%
import nltk

# %%
df = pd.read_csv('subtaskA_train.csv').drop(columns=['Id'])

# %%
df.head()
# Out:
#                                         comment_text  conspiratorial
# 0  ⚡Se non ci fossero soldati non ci sarebbero gu...               0
# 1  21/08/21]( [PRE-PRINT]\n\n📄__ "Shedding of Inf...               1
# 2  PAURA E DELIRIO ALLA CNN: IL MINISTERO DELLA V...               1
# 3  L'Aspirina non aumenta la sopravvivenza dei pa...               0
# 4  L'Italia non puo' dare armi lo vieta la Costit...               0

# %%
df.shape
# Out:
# (1842, 2)

# %%
found=0
for e in list(df.columns):
    if df[e].isna().any():
        found+=1
        print(e, df[e].isna().sum())
if found==0:
  print('No NaN values found')
# Out:
# No NaN values found

# %%
ax = sns.countplot(data=df, x='conspiratorial')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()

# %% [markdown]
# ## NLTK preprocessing

# %% [markdown]
# ### distribuzione parole

# %%
import re
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
punteggiatura = ['.', ',', ':', ';', '?', '!', '--', '-', '(', ')', '``', "''", '#', '$', '[', ']', '``', '_', "''", '*', '...']

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('italian'))

def clean_text(text, lower=False):
    """ text: a string
        return: modified initial string """
    if lower:
      text = text.lower() # lowercase text
    text = re.sub(r'[/(){}\[\]\|@,;]', ' ', text) # substitute the matched string with space.
    text = re.sub(r'[#+_]', '', text) # substitute bad symbols with nothing.
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text

#df['comment_text'] = df['comment_text'].apply(clean_text)

# %%
df.head(10)
# Out:
#                                         comment_text  conspiratorial
# 0  ⚡Se non ci fossero soldati non ci sarebbero gu...               0
# 1  21/08/21]( [PRE-PRINT]\n\n📄__ "Shedding of Inf...               1
# 2  PAURA E DELIRIO ALLA CNN: IL MINISTERO DELLA V...               1
# 3  L'Aspirina non aumenta la sopravvivenza dei pa...               0
# 4  L'Italia non puo' dare armi lo vieta la Costit...               0
# 5       Ma non siete stufi di essere presi in giro??               1
# 6  **Ritengo questo audio piuttosto importante**:...               1
# 7  ‼️ DIFFERENZA TRA SANGUE VACCINATO E NON VACCI...               1
# 8  Panzana pazzesca del leghista Siri: le misure ...               1
# 9  Tesla voleva portare a tutti energia gratuita ...               0

# %%
tokens = list()

for row in df.comment_text:
    tokens_sent = nltk.word_tokenize(row)
    for token in tokens_sent:
      if not token.isnumeric() and token not in punteggiatura:
        tokens.append(token)

    #tokens += tokens_sent

print('tokens:', len(tokens),
      '\nvocabulary:', len(set(tokens)),
      '\nTTR:', len(set(tokens))/len(tokens))
# Out:
# tokens: 92233
# vocabulary: 17683
# TTR: 0.19172096754957554

# %%
tokens[:50]
# Out:
# ['⚡Se',
#  'non',
#  'ci',
#  'fossero',
#  'soldati',
#  'non',
#  'ci',
#  'sarebbero',
#  'guerre',
#  '21/08/21',
#  'PRE-PRINT',
#  '📄__',
#  'Shedding',
#  'of',
#  'Infectious',
#  'SARS-CoV-2',
#  'Despite',
#  'Vaccination',
#  '🇮🇹',
#  'Diffusione',
#  'del',
#  'SARS-CoV-2',
#  'nonostante',
#  'la',
#  'vaccinazione',
#  '__',
#  '📊',
#  'La',
#  'variante',
#  'Delta',
#  'del',
#  'SARS-CoV-2',
#  'può',
#  'causare',
#  'elevate',
#  'cariche',
#  'virali',
#  'è',
#  'al',
#  'trasmissibile',
#  'e',
#  'contiene',
#  'mutazioni',
#  'che',
#  'conferiscono',
#  'una',
#  'fuga',
#  'immunitaria',
#  'parziale',
#  'le']

# %%
words, freqs = np.unique(tokens, return_counts=True)[0], np.unique(tokens, return_counts=True)[1]

sorted_freqs = sorted(zip(freqs, words), reverse=True)
sorted_frequencies, sorted_words = zip(*sorted_freqs)

# %%
plt.bar(sorted_words[:200], sorted_frequencies[:200])
plt.xlabel('Parole')
plt.ylabel('Frequenza')

plt.xticks([])

#plt.savefig('zipf.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### distribuzione POS

# %%
#punteggiatura = ('.', ',', ':', ';', '?', '!', '--', '-', '(', ')', '``', "''", '#', '$')
aggettivi = ('JJ', 'JJR', 'JJS')
sostantivi = ('NN', 'NNS', 'NNP', 'NNPS')
verbi = ('VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'MD')
avverbi = ('RB', 'RBR', 'RBS', 'WRB')
articoli = ('DT',)
preposizioni = ('IN', 'RP')
congiunzioni = ('CC', 'IN')
pronomi = ('PRP', 'PRPS', 'WP', 'WPS')

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
tok_pos = nltk.pos_tag(tokens) #(token, POS)

pos = list() #pos only
for tok, p in tok_pos:
    if p not in punteggiatura:
        pos.append(p)

# %%
pos_count= list()
for p, count in zip(np.unique(pos, return_counts=True)[0], np.unique(pos, return_counts=True)[1]):
    pos_count.append((count,p))

sorted(pos_count, reverse=True)[:10]
# Out:
# [(52270, 'NN'),
#  (15906, 'NNP'),
#  (8101, 'JJ'),
#  (3762, 'FW'),
#  (3292, 'IN'),
#  (2066, 'VBP'),
#  (1713, 'VBZ'),
#  (1275, 'DT'),
#  (907, 'RB'),
#  (703, 'VBD')]

# %%
def mergePOS(pos_lst, pos_counts, pos_dict, pos_key):
    for count, pos in pos_counts:
        if pos in pos_lst:
            pos_dict[pos_key]= pos_dict.get(pos_key) + count

# %%
pos_grouped = {
    'aggettivi':0,
    'sostantivi':0,
    'verbi':0,
    'avverbi':0,
    'articoli':0,
    'preposizioni':0,
    'congiunzioni':0
}

mergePOS(aggettivi, pos_count, pos_grouped, 'aggettivi')
mergePOS(sostantivi, pos_count, pos_grouped, 'sostantivi')
mergePOS(verbi, pos_count, pos_grouped, 'avverbi')
mergePOS(avverbi, pos_count, pos_grouped, 'verbi')
mergePOS(articoli, pos_count, pos_grouped, 'articoli')
mergePOS(preposizioni, pos_count, pos_grouped, 'preposizioni')
mergePOS(congiunzioni, pos_count, pos_grouped, 'congiunzioni')

# %%
pos_grouped
# Out:
# {'aggettivi': 8111,
#  'sostantivi': 68741,
#  'verbi': 923,
#  'avverbi': 4959,
#  'articoli': 1275,
#  'preposizioni': 3307,
#  'congiunzioni': 3394}

# %%
sorted_pos = {k: v for k, v in sorted(pos_grouped.items(), key=lambda item: item[1], reverse=True)}

# %%
plt.bar(sorted_pos.keys(), sorted_pos.values())

#plt.xticks(rotation=45)
plt.show()

# %%
pos_grouped['verbi']/pos_grouped['sostantivi']
# Out:
# 0.013427212289608822

# %% [markdown]
# ### NE

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
def extract_NE(tok_pos, NE):
  NEs = list()
  freq_NEs = list()

  # si ottiene l'albero, quindi si controlla che ci siano nodi intermedi etichettati
  # con una data NE
  ent_nom = nltk.ne_chunk(tok_pos)
  for nodo in ent_nom:
      name_ent = ''
      if hasattr(nodo, 'label'):
          if nodo.label() == NE:
              for figlio in nodo.leaves():
                  # si prende il primo elemento di ogni foglia, corrispondente al token,
                  # quindi si aggiunge la stringa ad una lista
                  name_ent += ' ' + figlio[0]
              NEs.append(name_ent)

  for ne in list(set(NEs)):
      freq = NEs.count(ne)
      freq_NEs.append((freq, ne))
  freq_NEs = sorted(freq_NEs, reverse=True)

  return freq_NEs

# %%
freq_persone = extract_NE(tok_pos, 'PERSON')

# %%
freq_persone[:15]
# Out:
# [(81, ' Non'),
#  (42, ' Trump'),
#  (40, ' Questo'),
#  (32, ' Putin'),
#  (28, ' Questa'),
#  (28, ' Per'),
#  (26, ' Sono'),
#  (26, ' Delta'),
#  (24, ' Draghi'),
#  (21, ' Stati Uniti'),
#  (21, ' Perché'),
#  (19, ' Covid'),
#  (16, ' Stato'),
#  (15, ' Paesi'),
#  (15, ' Abbiamo')]

# %%
STOPWORDS = set(stopwords.words('italian'))
' Questo'.split()[0].lower() in STOPWORDS
# Out:
# True

# %%
persone_dict = dict()
threshold = 1
threshold_token = 3

for count, token in freq_persone:
  if count >= threshold and len(token.split()[0]) > threshold_token and token.split()[0].lower() not in STOPWORDS:
    persone_dict[token] = count

# %%
freq_gpe = extract_NE(tok_pos, 'GPE')

# %%
freq_gpe[:15]
# Out:
# [(97, ' Russia'),
#  (86, ' Italia'),
#  (50, ' Ucraina'),
#  (21, ' Europa'),
#  (15, ' Cina'),
#  (14, ' Paese'),
#  (11, ' Taiwan'),
#  (11, ' Israele'),
#  (11, ' Germania'),
#  (10, ' New York'),
#  (10, ' Chi'),
#  (9, ' Roma'),
#  (9, ' America'),
#  (7, ' Polonia'),
#  (7, ' India')]

# %%
gpe_dict = dict()
threshold = 1
threshold_token = 2

for count, token in freq_gpe:
  if count >= threshold and len(token.split()[0]) > threshold_token and token.split()[0].lower() not in STOPWORDS:
    gpe_dict[token] = count

# %% [markdown]
# ## wordcloud

# %%
from wordcloud import WordCloud, ImageColorGenerator

# %%
persone_merged = list()
for token in list(persone_dict.keys()): #list(df[df['conspiratorial'] == 1].comment_text):
  freq = persone_dict[token]
  token += ' '
  token = (token * freq)# * persone_dict[token])
  persone_merged += (token.split())

# %%
import random

text = ''
random.shuffle(persone_merged)
for token in persone_merged:
  text += token + ' '
text
# Out:
# "Mosca Engelbrecht Gregg Bibbia Vogliono Fetterman Musk Phillips Institute Romagna Columbia Clinton Costoro Ho Edificio Conte Senza Bassi Paesi Wave Matteo Dopo Paciolla Gates Sfuggito Finora Saper Arena __Un Pensiamo Bergamo Roberto Siete Uniti Europa Meno Deep Zelensky Bailey Di Johnson Lorenzin Uscito Cosentino Domandati Salvini Lega Clinton Reich Delta Systems Putin Uniti Covid Ritardati Paolo Biden Baker Zelensky Ebbene Andrea Uniti Sara Bilderberg La Davos Stramezzi Per Devo Phillips Gruppo Musk Reich La Paesi Unite Bill Tuttavia Deep Great Francia Casa Uniti Quotidiano Milani Popolare Grillo Donald Airbus Behanzin Italia Bank Sergei Letta Bilderberg Iscriviti Informazione Ormai Gloria Trump Elon Sono Stati Bilancio Verna Trump Putin Organization Libertà Ronzulli Sudden Hunter Trump Yuri Azov Reset Poroshenko Zanotelli II Lira Si Paesi Silver Tipo Malone Durham Cosa Biscardi Stato George Vaccini Lysychansk Dopo Berlusca Trump Vescovi Regno Putin Safire Vedrete Macron Gonzalo Corpo Boris Prasad Ghislaine Tuttavia La Potrai Robert Freddy Fonte Infine Viktor Maria Antigua Yalda Patel Deutsche Juarez Allora Gutemberg Alex Internazionale Magari Dodter Brasile Vaccini Dalla Così Bomob Spunta Però MI6 Fondo Briatore Costa Giorgio Trump Giovedì Franco Nespresso Draghi Ordine Rosso Omicron Pfizer Basta Presto Youtube Brexit Finalmente Salute Bergoglio Erich Ancora Erich Etage Il Putin Paese Corriere Steele Unito Bizzarri Cernobyl Uniti Trump Omicron Esteri Scholz Scavino Browne Jeff Bezos Clinton Stati Infectious Andrea Unite Davos Stato__ Oliviero Vi La RAI Gates Alejandro Mann Regno Jcronazisti Amato Arabia Effetto Australia Barack Ecco Trump Ornella Nel Casa Questo Trieste Raggi Verità Firenze Giorgia Paesi Massí Minchia Sjogren Finlandia Sussmann Roma Conte Lourie Scavino Stefano Putin Uniti Paesi Konstantin Stato Lavrov Aspettero Chigi Dark Sgarbi Clinton Soros Bonafede Diabetes Devono Coop Covid Lorenzin Azov USA Davvero Shinzo Stato Studio Moriggia Bergoglio Senza Ecco Risposta Meloni Paesi Matteo Draghi E Colonna Lavrov Romeo Sicuro Universo1 Zakharova Sanità Zelensky Green Solo Solo Pfizer Mattarella Sushko Stati Müller Giorgio Quirinale Fox Pentagono Politici __ Twich Europea Meloni Wang Aleksandr NO Forni Bella Politica Donbass Ecco Putin Geim Sicuramente Phillips Novoselov Auli Nazioni Bill Guerra Ucraino Mattarella Agosto Paesi Stati Attenzione Inoltre Giordano Vaccines C Delta Podcast Buon Italia Ukraini Nessun Dragula Bright Pfizer Pen Mario Pericoloso Kevin Soros Milano Napoli Roger Peter Niente Reuters Strasburgo Giorgio Richard Merrick Covid Puzzer Sarà Omicidio John Stati Phillips Nazioni Trump Ricciardi Farina Podcast Reset Scifo Giustizia Le È Ministero Trump Luglio Luisa Reset Cingolani Oppure Super Netta Wade Podcast Gates Maxwell Cosa Trieste Paesi Davvero Trump Davos Simoni Include Speranza Inoltre Putin Gustave Hillary Istat Legge Elon Mentre Doniesk Prima Zurawik Artemis Holzeisen Mules Banche Giugno Flynn Epstein Bitcoin Cosa Draghi Macron Anxiety Covid Orban Gates Vivere Borghi Biden Anon Iosefina Game Siccome Safire Avvocato Aeroflot Bianca Vogliamo Stato Università Clementina Unito Trump Cremlino Costituzione Pfizer Vedendo AZOV Mario Donetsk Maglie Trieste Russie Scholz Silvana Draghi Uruguay È Lurpak Dott Sapienza Francesca Pass Salute Imitatela Non Disturbi Stati Moderna Le Unito Putin Mules Brusaferro Latina Massimo Alexander Facebook Generale Bellanova Strasburgo Putin Salvini Nessuno Bruce Abbiamo McAfee Auguri Milano Fulton Grande Welch Cosa Se Epstein Rete4 __È Moderna Popolare John Ecco Notizia Ucrania Oltre Diritti Vorrei Legione Link Carta È Oleg Rispetto Podcast Vedremo Quando Daria Nuovo Draghi John Quando Dott Israele Militari Marco Siri Catherine Plan Stati Ricevo Delta Putin Grillo Per Draghi Trudeau Piero Cecchi Infatti Twitter Death Nationale Alcuni Lavrov Mondiale Sussurrare Piers Borodianka Johnson Luisa Messico Amburgo Verità Lega Governo Delta Interactive Zelenko Facebook Abiga ...

# %%
conspiratorial_msg_cloud = WordCloud(width=520,
                                     height=260,
                                     stopwords=STOPWORDS,
                                     #max_font_size=50,
                                     #background_color = "black", colormap = 'Pastel1'
                                     ).generate(text)
plt.figure(figsize=(16,10))
plt.imshow(conspiratorial_msg_cloud, interpolation = 'bilinear')
plt.axis('off') # turn off axis
plt.show()

# %%
gpe_merged = list()
for token in list(gpe_dict.keys()): #list(df[df['conspiratorial'] == 1].comment_text):
  freq = gpe_dict[token]
  token += ' '
  token = (token * freq)# * persone_dict[token])
  gpe_merged += (token.split())

# %%
text = ''
random.shuffle(gpe_merged)
for token in gpe_merged:
  text += token + ' '
text
# Out:
# 'Washington Italia Russo Davos Lombardia Ucraina Romania Calabria British Russia Roma Russia Europa Paese Italia Newsmax Palermo Ucraina Draghi Francia Russia India Cina Ricorda Russia Australia Italia Sparta Europa Italia Russia Auspicano Italia Paese Russia York Pfizer Russia Russia Ucraina Chiunque Germania Lituania Europa Georgia Medicine Italia India Ucraina Europa Scemo Quebec Russia Florida Inghilterra Natalia Pennsylvania Russia New Europa Ucraina Porca Svizzera Medicina Minnesota Russia Cisgiordania Italia Russia New Russia Italia Russia Australia Europa Italia Italia Russia Taiwan Argentina Campania Florida Massoneria Ucraina Calabria Nord Fratelli Canada Beirut Russia Mosse Russia Mosca SORDINA Ucraina Russia Ungheria Italia Ucraina Italia Italia Russia India Iceland__ Paese Roma Russia Tuttavia Florida Davos Germania Catania America Cina Australia Roma Serbia Paesi Midland Canada Italia Green Russia Italia Russia Italia Russia Hong Russia Cina South Germania Russia Italia Cina Taiwan Russia Ucraina Cornovaglia Europa Russia Russia Chiamate Spazio Italia Russia Europa Cina Paese Jordan Grecia Taiwan Gregg Norvegia Taiwan Italia Viral Argentina Alpha Italia Ivermectin Italia York Taiwan Ucraina Bologna Russia Taiwan Ucraina Giappone America Italia Cina Indomethacin Russia Israele Russia Florida Grecia Parigi Paese Korea York Turchia Paese York Ucraina Dentro Italia Coronavirus Israele Colonia Russia Italia Mosca TANTI Australia Ucraina Fratoianni Italiano Argentina Maryland CORSIA Russia Ucraina Taiwan African Russia Italia Elliott Ucraina Umbria Canale Taiwan Colorado Italia British Serbia Russia Euromaidan California Granato Virology Europe Russia York Inghilterra Sud Taiwan Ucraina Russia York Italia Italia Italia Fratelli Italia Salute Valencia Francia Europa Russia Italia Parlamento Perù Ucraina Cina Francia Macron Italia Italia Russia Russia Chinnici Piazza Porcaccia Roma ITALIA Italia Paese Porteremo Inghilterra York Russia Grecia Bonomi Russia Italia New America Israele Italia Italia Ucraina European Lamorgese Quando Londra America Norvegia Chissà Latina Russia Argentina Russia Germania Norimberga Italia Bellaria Russia New Istanbul Groenlandia Italia Europa Euromomo Francia Russia Russia Italia Maryland America Maryland Italia Israele Ucraina Ungheria Crollano Italia Wales Mosca Russia Ucraina Italia Ucraina Italia Paese Italia Ucraina Israele Cina Italia Bucha Cancer__ India Maggiore Davos New Italia Riprendendo Fratelli Ucraina Lombardia Italia Melania Roma Europa New Austria Polonia Italia Russia Lettonia Italia Calenda Russia Angeles Corea Catania Ucraina Danimarca Ucraina Washington Regina Russia Europa Italia Corona Toscano Germania Frajese Green India Ucraina Cina India Italia Slovenia Israele Calenda Russia Coronavirus Arrivals Italia Volevo Italia Europa Polonia Canada Cina Ucraina Spagna Sono Israele New Ucraina Belgio Russia Russia Roma Ucraina Ucraina Europa Russia Paese Calenda Russia Russia New Spagna Russia Ungheria Calenda Cina Meloni York Germania Mosca Australia Ucraina Russia Polonia Cina Durham Los Russia Ucraina Spagna America Polonia Ucraina Russia Italia Russia Washington Ucraina Europa Alitalia Italia Titolo Russia Italia Russia Australia Italia Russia Russia Ucraina Europa Italia Oggi Italia Russia Portale Italia Spagna Arabia Polonia Albania Russia Europa Minnesota Italia America Ieri Viganò Crolla Italia Russia Europa Washington Russia Roma Canada Tachipirina Kong Odessa Germania Male Texas Italia Green Italia Portavoce Davos Italia Ucraina Messico Cercano Ucraina Padova Russia Brasile Germania Pennsylvania Ucrania Kazakistan Cina Boeing Ethereum Chiarire Studi Russia Paese Texas Frajese Taiwan Paese Italia Bethesda Strano Italia Gregg Italia Russia America Hong Chiaro Russia Immagina Africa Spagna Israele Italia Taking Chissà Ucraina Sardegna Grazie Paese Chiede India Ucraina Lombardia Italia Italia Israele Washington Soprattutto Spagna Russia Norimberga Sicilia Paese Russia Russi ...

# %%
conspiratorial_msg_cloud = WordCloud(width=520,
                                     height=260,
                                     stopwords=STOPWORDS,
                                     #max_font_size=50,
                                     #background_color = "black", colormap = 'Pastel1'
                                     ).generate(text)
plt.figure(figsize=(16,10))
plt.imshow(conspiratorial_msg_cloud, interpolation = 'bilinear')
plt.axis('off') # turn off axis
plt.show()

# %% [markdown]
# ## Sentiment analysis

# %%
# !pip uninstall vaderSentiment
# !pip install vader-multi
# Out:
# WARNING: Skipping vaderSentiment as it is not installed.
# Requirement already satisfied: vader-multi in /usr/local/lib/python3.10/dist-packages (3.2.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vader-multi) (2.31.0)
# Requirement already satisfied: translatte in /usr/local/lib/python3.10/dist-packages (from vader-multi) (0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vader-multi) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vader-multi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vader-multi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vader-multi) (2023.7.22)

# %% [markdown]
# VADER è un lexicon pensato solo per l'inglese
#
# vader-multi effettua una traduzione della frase in inglese tramite Google Translate API e puoi effettua la SA tramite la libreria "Vader" in inglese.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
analyzer.polarity_scores("VADER is smart, handsome, and funny.")
# Out:
# {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316}

# %%
analyzer.polarity_scores("VADER è MOLTO INTELLIGENTE, bello e DIVERTENTE!!!")
# Out:
# {'neg': 0.0, 'neu': 0.224, 'pos': 0.776, 'compound': 0.9417}

# %%
print(df['comment_text'][3])
analyzer.polarity_scores(df['comment_text'][3])
# Out:
# L'Aspirina non aumenta la sopravvivenza dei pazienti ricoverati in ospedale per Covid-19,
# {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.2411}

# %%
df_vader = pd.DataFrame(columns=['text', 'neg', 'neu', 'pos','compound', 'conspiratorial'])

# %%
for i, row in tqdm(df.iterrows(), total=len(df)):
    df_vader.loc[i, 'text'] = row['comment_text']
    df_vader.loc[i, 'conspiratorial'] = row['conspiratorial']
    try:
      score = analyzer.polarity_scores(row['comment_text'])
      for key in score.keys():
          df_vader.loc[i, key] = score[key]
    except IndexError:
      continue
    df_vader.loc[i, 'conspiratorial'] = row['conspiratorial']

df_vader.head()
# Out:
#   0%|          | 0/1842 [00:00<?, ?it/s]
#                                                 text    neg    neu    pos  \
# 0  ⚡Se non ci fossero soldati non ci sarebbero gu...  0.145  0.661  0.193
# 1  21/08/21]( [PRE-PRINT]\n\n📄__ "Shedding of Inf...  0.032  0.929  0.039
# 2  PAURA E DELIRIO ALLA CNN: IL MINISTERO DELLA V...  0.101  0.807  0.092
# 3  L'Aspirina non aumenta la sopravvivenza dei pa...  0.179  0.821    0.0
# 4  L'Italia non puo' dare armi lo vieta la Costit...  0.215   0.56  0.225
#
#   compound conspiratorial
# 0   0.1838              0
# 1  -0.0772              1
# 2  -0.8869              1
# 3  -0.2411              0
# 4   0.0274              0

# %%
df_vader.shape
# Out:
# (1842, 6)

# %%
sns.boxplot(data=df_vader, x='conspiratorial', y='compound')
plt.show()

# %%
sns.barplot(data=df_vader, x='conspiratorial', y='compound')
plt.show()

# %% [markdown]
# i post cospirazionisti tendono ad avere una sentiment più negativa

# %%
df_vader.columns[1:4]
# Out:
# Index(['neg', 'neu', 'pos'], dtype='object')

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

for i, col in enumerate(df_vader.columns[1:4]):
    sns.barplot(data=df_vader, x='conspiratorial', y=col,
                order=list(reversed(df_vader.conspiratorial.unique())), ax=axs[i])

plt.tight_layout()

#plt.savefig('vader_barplot.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# notare la scala dei dati, il sentimento negativo è comunque minimo e non va mai oltre lo 0.12

# %%
df_vader['compound'].mean(), df_vader['compound'].std()
# Out:
# (-0.05408875611080936, 0.5587746794069434)

# %%
plt.hist(df_vader['compound'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:837: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:838: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
fig, axs = plt.subplots(1, 4, figsize=(12, 2))

for i, col in enumerate(df_vader.columns[1:5]):
  ax=axs[i]
  ax.hist(df_vader[col])
  ax.set_title(col)

plt.tight_layout()

#plt.savefig('vader_barplot.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:837: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:838: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
